# %%
# !pip install ultralytics==8.0.196 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5597.6/8062.4 GB disk)

# %%
from ultralytics import YOLO

data = '/kaggle/input/dataset-800/DatasetRandom2/data.yaml'

# Initialize the YOLO model
model = YOLO('yolov8n.pt')

model.tune(data=data, epochs=20, iterations=150, optimizer='AdamW', plots=True, save=True, val=True)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 22.9MB/s]
# Tuner: Initialized Tuner instance with 'tune_dir=runs/detect/tune'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/150 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# New https://pypi.org/project/ultralytics/8.2.19 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...
