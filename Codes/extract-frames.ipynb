# %%
import cv2
import os

def extract_frames(video_path, output_folder, interval_seconds):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video file {video_path}.")
        return
    
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        # Get the current frame count and calculate the time in seconds
        current_frame = cap.get(cv2.CAP_PROP_POS_FRAMES)
        fps = cap.get(cv2.CAP_PROP_FPS)
        current_time_seconds = current_frame / fps
        
        # Check if it's time to save the frame based on the interval
        if current_time_seconds >= frame_count * interval_seconds:
            # Save the frame
            frame_path = os.path.join(output_folder, f"frame_{frame_count}.jpg")
            cv2.imwrite(frame_path, frame)
            print(f"Saved frame {frame_count} of {video_path} at {current_time_seconds:.2f} seconds")
            frame_count += 1
    
    # Release the video capture object
    cap.release()

def extract_frames_from_folder(input_folder, output_folder, interval_seconds):
    # Iterate through all files in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith((".mp4", ".avi", ".mov")):  # Check if file is a video
            video_path = os.path.join(input_folder, filename)
            output_subfolder = os.path.join(output_folder, os.path.splitext(filename)[0])
            extract_frames(video_path, output_subfolder, interval_seconds)
        else:
            print(f"Ignoring non-video file: {filename}")

input_folder = "/kaggle/input/dataset2305"  # Folder containing all video files
output_folder = "data7"  # Folder to save extracted frames
interval_seconds = 5  # Time interval to extract frames (in seconds)

extract_frames_from_folder(input_folder, output_folder, interval_seconds)
# Out:
# Saved frame 0 of /kaggle/input/dataset2305/(3).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(3).mp4 at 5.04 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(3).mp4 at 10.03 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(3).mp4 at 15.03 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(3).mp4 at 20.02 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(3).mp4 at 25.02 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(9).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(9).mp4 at 5.00 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(9).mp4 at 10.00 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(9).mp4 at 15.01 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(9).mp4 at 20.01 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(9).mp4 at 25.01 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(9).mp4 at 30.01 seconds
# Saved frame 7 of /kaggle/input/dataset2305/(9).mp4 at 35.02 seconds
# Saved frame 8 of /kaggle/input/dataset2305/(9).mp4 at 40.02 seconds
# Saved frame 9 of /kaggle/input/dataset2305/(9).mp4 at 45.02 seconds
# Saved frame 10 of /kaggle/input/dataset2305/(9).mp4 at 50.02 seconds
# Saved frame 11 of /kaggle/input/dataset2305/(9).mp4 at 55.03 seconds
# Saved frame 12 of /kaggle/input/dataset2305/(9).mp4 at 60.03 seconds
# Saved frame 13 of /kaggle/input/dataset2305/(9).mp4 at 65.03 seconds
# Saved frame 14 of /kaggle/input/dataset2305/(9).mp4 at 70.03 seconds
# Saved frame 15 of /kaggle/input/dataset2305/(9).mp4 at 75.03 seconds
# Saved frame 16 of /kaggle/input/dataset2305/(9).mp4 at 80.04 seconds
# Saved frame 17 of /kaggle/input/dataset2305/(9).mp4 at 85.04 seconds
# Saved frame 18 of /kaggle/input/dataset2305/(9).mp4 at 90.00 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(18).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(18).mp4 at 5.02 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(18).mp4 at 10.01 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(18).mp4 at 15.03 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(18).mp4 at 20.01 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(18).mp4 at 25.04 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(18).mp4 at 30.02 seconds
# Saved frame 7 of /kaggle/input/dataset2305/(18).mp4 at 35.00 seconds
# Saved frame 8 of /kaggle/input/dataset2305/(18).mp4 at 40.03 seconds
# Saved frame 9 of /kaggle/input/dataset2305/(18).mp4 at 45.01 seconds
# Saved frame 10 of /kaggle/input/dataset2305/(18).mp4 at 50.03 seconds
# Saved frame 11 of /kaggle/input/dataset2305/(18).mp4 at 55.02 seconds
# Saved frame 12 of /kaggle/input/dataset2305/(18).mp4 at 60.00 seconds
# Saved frame 13 of /kaggle/input/dataset2305/(18).mp4 at 65.02 seconds
# Saved frame 14 of /kaggle/input/dataset2305/(18).mp4 at 70.01 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(8).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(8).mp4 at 5.00 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(8).mp4 at 10.01 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(8).mp4 at 15.01 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(8).mp4 at 20.02 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(8).mp4 at 25.02 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(8).mp4 at 30.03 seconds
# Saved frame 7 of /kaggle/input/dataset2305/(8).mp4 at 35.03 seconds
# Saved frame 8 of /kaggle/input/dataset2305/(8).mp4 at 40.04 seconds
# Saved frame 9 of /kaggle/input/dataset2305/(8).mp4 at 45.00 seconds
# Saved frame 10 of /kaggle/input/dataset2305/(8).mp4 at 50.01 seconds
# Saved frame 11 of /kaggle/input/dataset2305/(8).mp4 at 55.01 seconds
# Saved frame 12 of /kaggle/input/dataset2305/(8).mp4 at 60.02 seconds
# Saved frame 13 of /kaggle/input/dataset2305/(8).mp4 at 65.02 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(12).mp4 at 0.03 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(12).mp4 at 5.02 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(12).mp4 at 10.00 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(12).mp4 at 15.02 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(12).mp4 at 20.01 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(12).mp4 at 25.03 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(12).mp4 at 30.01 seconds
# Saved frame 7 of /kaggle/input/dataset2305/(12).mp4 at 35.03 seconds
# Saved frame 8 of /kaggle/input/dataset2305/(12).mp4 at 40.02 seconds
# Saved frame 9 of /kaggle/input/dataset2305/(12).mp4 at 45.00 seconds
# Saved frame 10 of /kaggle/input/dataset2305/(12).mp4 at 50.02 seconds
# Saved frame 11 of /kaggle/input/dataset2305/(12).mp4 at 55.00 seconds
# Saved frame 12 of /kaggle/input/dataset2305/(12).mp4 at 60.02 seconds
# Saved frame 13 of /kaggle/input/dataset2305/(12).mp4 at 65.01 seconds
# Saved frame 14 of /kaggle/input/dataset2305/(12).mp4 at 70.03 seconds
# Saved frame 15 of /kaggle/input/dataset2305/(12).mp4 at 75.01 seconds
# Saved frame 16 of /kaggle/input/dataset2305/(12).mp4 at 80.03 seconds
# Saved frame 17 of /kaggle/input/dataset2305/(12).mp4 at 85.02 seconds
# Saved frame 18 of /kaggle/input/dataset2305/(12).mp4 at 90.00 seconds
# Saved frame 19 of /kaggle/input/dataset2305/(12).mp4 at 95.02 seconds
# Saved frame 20 of /kaggle/input/dataset2305/(12).mp4 at 100.00 seconds
# Saved frame 21 of /kaggle/input/dataset2305/(12).mp4 at 105.02 seconds
# Saved frame 22 of /kaggle/input/dataset2305/(12).mp4 at 110.01 seconds
# Saved frame 23 of /kaggle/input/dataset2305/(12).mp4 at 115.03 seconds
# Saved frame 24 of /kaggle/input/dataset2305/(12).mp4 at 120.01 seconds
# Saved frame 25 of /kaggle/input/dataset2305/(12).mp4 at 125.03 seconds
# Saved frame 26 of /kaggle/input/dataset2305/(12).mp4 at 130.02 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(7).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(7).mp4 at 5.01 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(7).mp4 at 10.02 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(7).mp4 at 15.04 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(7).mp4 at 20.00 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(7).mp4 at 25.02 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(7).mp4 at 30.03 seconds
# Saved frame 7 of /kaggle/input/dataset2305/(7).mp4 at 35.04 seconds
# Saved frame 8 of /kaggle/input/dataset2305/(7).mp4 at 40.01 seconds
# Saved frame 9 of /kaggle/input/dataset2305/(7).mp4 at 45.02 seconds
# Saved frame 10 of /kaggle/input/dataset2305/(7).mp4 at 50.03 seconds
# Saved frame 11 of /kaggle/input/dataset2305/(7).mp4 at 55.00 seconds
# Saved frame 12 of /kaggle/input/dataset2305/(7).mp4 at 60.01 seconds
# Saved frame 13 of /kaggle/input/dataset2305/(7).mp4 at 65.03 seconds
# Saved frame 14 of /kaggle/input/dataset2305/(7).mp4 at 70.04 seconds
# Saved frame 15 of /kaggle/input/dataset2305/(7).mp4 at 75.01 seconds
# Saved frame 16 of /kaggle/input/dataset2305/(7).mp4 at 80.02 seconds
# Saved frame 17 of /kaggle/input/dataset2305/(7).mp4 at 85.03 seconds
# Saved frame 18 of /kaggle/input/dataset2305/(7).mp4 at 90.04 seconds
# Saved frame 19 of /kaggle/input/dataset2305/(7).mp4 at 95.01 seconds
# Saved frame 20 of /kaggle/input/dataset2305/(7).mp4 at 100.02 seconds
# Saved frame 21 of /kaggle/input/dataset2305/(7).mp4 at 105.04 seconds
# Saved frame 22 of /kaggle/input/dataset2305/(7).mp4 at 110.00 seconds
# Saved frame 23 of /kaggle/input/dataset2305/(7).mp4 at 115.02 seconds
# Saved frame 24 of /kaggle/input/dataset2305/(7).mp4 at 120.03 seconds
# Saved frame 25 of /kaggle/input/dataset2305/(7).mp4 at 125.04 seconds
# Saved frame 26 of /kaggle/input/dataset2305/(7).mp4 at 130.01 seconds
# Saved frame 27 of /kaggle/input/dataset2305/(7).mp4 at 135.02 seconds
# Saved frame 28 of /kaggle/input/dataset2305/(7).mp4 at 140.03 seconds
# Saved frame 29 of /kaggle/input/dataset2305/(7).mp4 at 145.00 seconds
# Saved frame 30 of /kaggle/input/dataset2305/(7).mp4 at 150.01 seconds
# Saved frame 31 of /kaggle/input/dataset2305/(7).mp4 at 155.03 seconds
# Saved frame 32 of /kaggle/input/dataset2305/(7).mp4 at 160.04 seconds
# Saved frame 33 of /kaggle/input/dataset2305/(7).mp4 at 165.01 seconds
# Saved frame 34 of /kaggle/input/dataset2305/(7).mp4 at 170.02 seconds
# Saved frame 35 of /kaggle/input/dataset2305/(7).mp4 at 175.03 seconds
# Saved frame 36 of /kaggle/input/dataset2305/(7).mp4 at 180.04 seconds
# Saved frame 37 of /kaggle/input/dataset2305/(7).mp4 at 185.01 seconds
# Saved frame 38 of /kaggle/input/dataset2305/(7).mp4 at 190.02 seconds
# Saved frame 39 of /kaggle/input/dataset2305/(7).mp4 at 195.03 seconds
# Saved frame 40 of /kaggle/input/dataset2305/(7).mp4 at 200.00 seconds
# Saved frame 41 of /kaggle/input/dataset2305/(7).mp4 at 205.01 seconds
# Saved frame 42 of /kaggle/input/dataset2305/(7).mp4 at 210.03 seconds
# Saved frame 43 of /kaggle/input/dataset2305/(7).mp4 at 215.04 seconds
# Saved frame 44 of /kaggle/input/dataset2305/(7).mp4 at 220.01 seconds
# Saved frame 45 of /kaggle/input/dataset2305/(7).mp4 at 225.02 seconds
# Saved frame 46 of /kaggle/input/dataset2305/(7).mp4 at 230.03 seconds
# Saved frame 47 of /kaggle/input/dataset2305/(7).mp4 at 235.04 seconds
# Saved frame 48 of /kaggle/input/dataset2305/(7).mp4 at 240.01 seconds
# Saved frame 49 of /kaggle/input/dataset2305/(7).mp4 at 245.02 seconds
# Saved frame 50 of /kaggle/input/dataset2305/(7).mp4 at 250.04 seconds
# Saved frame 51 of /kaggle/input/dataset2305/(7).mp4 at 255.00 seconds
# Saved frame 52 of /kaggle/input/dataset2305/(7).mp4 at 260.02 seconds
# Saved frame 53 of /kaggle/input/dataset2305/(7).mp4 at 265.03 seconds
# Saved frame 54 of /kaggle/input/dataset2305/(7).mp4 at 270.04 seconds
# Saved frame 55 of /kaggle/input/dataset2305/(7).mp4 at 275.01 seconds
# Saved frame 56 of /kaggle/input/dataset2305/(7).mp4 at 280.02 seconds
# Saved frame 57 of /kaggle/input/dataset2305/(7).mp4 at 285.03 seconds
# Saved frame 58 of /kaggle/input/dataset2305/(7).mp4 at 290.00 seconds
# Saved frame 59 of /kaggle/input/dataset2305/(7).mp4 at 295.01 seconds
# Saved frame 60 of /kaggle/input/dataset2305/(7).mp4 at 300.03 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(11).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(11).mp4 at 5.01 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(11).mp4 at 10.02 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(11).mp4 at 15.04 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(11).mp4 at 20.01 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(11).mp4 at 25.02 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(15).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(15).mp4 at 5.02 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(15).mp4 at 10.03 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(15).mp4 at 15.01 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(15).mp4 at 20.02 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(15).mp4 at 25.04 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(15).mp4 at 30.01 seconds
# Saved frame 7 of /kaggle/input/dataset2305/(15).mp4 at 35.03 seconds
# Saved frame 8 of /kaggle/input/dataset2305/(15).mp4 at 40.01 seconds
# Saved frame 9 of /kaggle/input/dataset2305/(15).mp4 at 45.02 seconds
# Saved frame 10 of /kaggle/input/dataset2305/(15).mp4 at 50.04 seconds
# Saved frame 11 of /kaggle/input/dataset2305/(15).mp4 at 55.01 seconds
# Saved frame 12 of /kaggle/input/dataset2305/(15).mp4 at 60.03 seconds
# Saved frame 13 of /kaggle/input/dataset2305/(15).mp4 at 65.01 seconds
# Saved frame 14 of /kaggle/input/dataset2305/(15).mp4 at 70.02 seconds
# Saved frame 15 of /kaggle/input/dataset2305/(15).mp4 at 75.04 seconds
# Saved frame 16 of /kaggle/input/dataset2305/(15).mp4 at 80.01 seconds
# Saved frame 17 of /kaggle/input/dataset2305/(15).mp4 at 85.03 seconds
# Saved frame 18 of /kaggle/input/dataset2305/(15).mp4 at 90.01 seconds
# Saved frame 19 of /kaggle/input/dataset2305/(15).mp4 at 95.02 seconds
# Saved frame 20 of /kaggle/input/dataset2305/(15).mp4 at 100.04 seconds
# Saved frame 21 of /kaggle/input/dataset2305/(15).mp4 at 105.01 seconds
# Saved frame 22 of /kaggle/input/dataset2305/(15).mp4 at 110.03 seconds
# Saved frame 23 of /kaggle/input/dataset2305/(15).mp4 at 115.01 seconds
# Saved frame 24 of /kaggle/input/dataset2305/(15).mp4 at 120.02 seconds
# Saved frame 25 of /kaggle/input/dataset2305/(15).mp4 at 125.04 seconds
# Saved frame 26 of /kaggle/input/dataset2305/(15).mp4 at 130.01 seconds
# Saved frame 27 of /kaggle/input/dataset2305/(15).mp4 at 135.03 seconds
# Saved frame 28 of /kaggle/input/dataset2305/(15).mp4 at 140.01 seconds
# Saved frame 29 of /kaggle/input/dataset2305/(15).mp4 at 145.02 seconds
# Saved frame 30 of /kaggle/input/dataset2305/(15).mp4 at 150.04 seconds
# Saved frame 31 of /kaggle/input/dataset2305/(15).mp4 at 155.01 seconds
# Saved frame 32 of /kaggle/input/dataset2305/(15).mp4 at 160.03 seconds
# Saved frame 33 of /kaggle/input/dataset2305/(15).mp4 at 165.01 seconds
# Saved frame 34 of /kaggle/input/dataset2305/(15).mp4 at 170.02 seconds
# Saved frame 35 of /kaggle/input/dataset2305/(15).mp4 at 175.04 seconds
# Saved frame 36 of /kaggle/input/dataset2305/(15).mp4 at 180.01 seconds
# Saved frame 37 of /kaggle/input/dataset2305/(15).mp4 at 185.03 seconds
# Saved frame 38 of /kaggle/input/dataset2305/(15).mp4 at 190.01 seconds
# Saved frame 39 of /kaggle/input/dataset2305/(15).mp4 at 195.02 seconds
# Saved frame 40 of /kaggle/input/dataset2305/(15).mp4 at 200.04 seconds
# Saved frame 41 of /kaggle/input/dataset2305/(15).mp4 at 205.01 seconds
# Saved frame 42 of /kaggle/input/dataset2305/(15).mp4 at 210.03 seconds
# Saved frame 43 of /kaggle/input/dataset2305/(15).mp4 at 215.01 seconds
# Saved frame 44 of /kaggle/input/dataset2305/(15).mp4 at 220.02 seconds
# Saved frame 45 of /kaggle/input/dataset2305/(15).mp4 at 225.04 seconds
# Saved frame 46 of /kaggle/input/dataset2305/(15).mp4 at 230.01 seconds
# Saved frame 47 of /kaggle/input/dataset2305/(15).mp4 at 235.03 seconds
# Saved frame 48 of /kaggle/input/dataset2305/(15).mp4 at 240.01 seconds
# Saved frame 49 of /kaggle/input/dataset2305/(15).mp4 at 245.02 seconds
# Saved frame 50 of /kaggle/input/dataset2305/(15).mp4 at 250.04 seconds
# Saved frame 51 of /kaggle/input/dataset2305/(15).mp4 at 255.01 seconds
# Saved frame 52 of /kaggle/input/dataset2305/(15).mp4 at 260.03 seconds
# Saved frame 53 of /kaggle/input/dataset2305/(15).mp4 at 265.00 seconds
# Saved frame 54 of /kaggle/input/dataset2305/(15).mp4 at 270.02 seconds
# Saved frame 55 of /kaggle/input/dataset2305/(15).mp4 at 275.04 seconds
# Saved frame 56 of /kaggle/input/dataset2305/(15).mp4 at 280.01 seconds
# Saved frame 57 of /kaggle/input/dataset2305/(15).mp4 at 285.03 seconds
# Saved frame 58 of /kaggle/input/dataset2305/(15).mp4 at 290.00 seconds
# Saved frame 59 of /kaggle/input/dataset2305/(15).mp4 at 295.02 seconds
# Saved frame 60 of /kaggle/input/dataset2305/(15).mp4 at 300.03 seconds
# Saved frame 61 of /kaggle/input/dataset2305/(15).mp4 at 305.01 seconds
# Saved frame 62 of /kaggle/input/dataset2305/(15).mp4 at 310.03 seconds
# Saved frame 63 of /kaggle/input/dataset2305/(15).mp4 at 315.00 seconds
# Saved frame 64 of /kaggle/input/dataset2305/(15).mp4 at 320.02 seconds
# Saved frame 65 of /kaggle/input/dataset2305/(15).mp4 at 325.03 seconds
# Saved frame 66 of /kaggle/input/dataset2305/(15).mp4 at 330.01 seconds
# Saved frame 67 of /kaggle/input/dataset2305/(15).mp4 at 335.03 seconds
# Saved frame 68 of /kaggle/input/dataset2305/(15).mp4 at 340.00 seconds
# Saved frame 69 of /kaggle/input/dataset2305/(15).mp4 at 345.02 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(17).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(17).mp4 at 5.01 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(17).mp4 at 10.03 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(17).mp4 at 15.00 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(17).mp4 at 20.02 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(17).mp4 at 25.03 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(17).mp4 at 30.01 seconds
# Saved frame 7 of /kaggle/input/dataset2305/(17).mp4 at 35.02 seconds
# Saved frame 8 of /kaggle/input/dataset2305/(17).mp4 at 40.03 seconds
# Saved frame 9 of /kaggle/input/dataset2305/(17).mp4 at 45.01 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(5).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(5).mp4 at 5.01 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(5).mp4 at 10.02 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(5).mp4 at 15.03 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(5).mp4 at 20.00 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(6).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(6).mp4 at 5.01 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(6).mp4 at 10.02 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(6).mp4 at 15.00 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(6).mp4 at 20.01 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(6).mp4 at 25.02 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(6).mp4 at 30.00 seconds
# Saved frame 7 of /kaggle/input/dataset2305/(6).mp4 at 35.01 seconds
# Saved frame 8 of /kaggle/input/dataset2305/(6).mp4 at 40.02 seconds
# Saved frame 9 of /kaggle/input/dataset2305/(6).mp4 at 45.00 seconds
# Saved frame 10 of /kaggle/input/dataset2305/(6).mp4 at 50.01 seconds
# Saved frame 11 of /kaggle/input/dataset2305/(6).mp4 at 55.02 seconds
# Saved frame 12 of /kaggle/input/dataset2305/(6).mp4 at 60.00 seconds
# Saved frame 13 of /kaggle/input/dataset2305/(6).mp4 at 65.01 seconds
# Saved frame 14 of /kaggle/input/dataset2305/(6).mp4 at 70.03 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(1).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(1).mp4 at 5.01 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(1).mp4 at 10.02 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(1).mp4 at 15.00 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(1).mp4 at 20.01 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(1).mp4 at 25.03 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(1).mp4 at 30.00 seconds
# Saved frame 7 of /kaggle/input/dataset2305/(1).mp4 at 35.01 seconds
# Saved frame 8 of /kaggle/input/dataset2305/(1).mp4 at 40.03 seconds
# Saved frame 9 of /kaggle/input/dataset2305/(1).mp4 at 45.00 seconds
# Saved frame 10 of /kaggle/input/dataset2305/(1).mp4 at 50.01 seconds
# Saved frame 11 of /kaggle/input/dataset2305/(1).mp4 at 55.03 seconds
# Saved frame 12 of /kaggle/input/dataset2305/(1).mp4 at 60.00 seconds
# Saved frame 13 of /kaggle/input/dataset2305/(1).mp4 at 65.02 seconds
# Saved frame 14 of /kaggle/input/dataset2305/(1).mp4 at 70.03 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(10).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(10).mp4 at 5.04 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(10).mp4 at 10.03 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(10).mp4 at 15.03 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(10).mp4 at 20.02 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(10).mp4 at 25.02 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(10).mp4 at 30.01 seconds
# Saved frame 7 of /kaggle/input/dataset2305/(10).mp4 at 35.01 seconds
# Saved frame 8 of /kaggle/input/dataset2305/(10).mp4 at 40.01 seconds
# Saved frame 9 of /kaggle/input/dataset2305/(10).mp4 at 45.00 seconds
# Saved frame 10 of /kaggle/input/dataset2305/(10).mp4 at 50.04 seconds
# Saved frame 11 of /kaggle/input/dataset2305/(10).mp4 at 55.03 seconds
# Saved frame 12 of /kaggle/input/dataset2305/(10).mp4 at 60.03 seconds
# Saved frame 13 of /kaggle/input/dataset2305/(10).mp4 at 65.02 seconds
# Saved frame 14 of /kaggle/input/dataset2305/(10).mp4 at 70.02 seconds
# Saved frame 15 of /kaggle/input/dataset2305/(10).mp4 at 75.02 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(14).mp4 at 0.03 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(14).mp4 at 5.00 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(14).mp4 at 10.00 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(14).mp4 at 15.00 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(14).mp4 at 20.00 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(14).mp4 at 25.00 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(14).mp4 at 30.00 seconds
# Saved frame 7 of /kaggle/input/dataset2305/(14).mp4 at 35.00 seconds
# Saved frame 8 of /kaggle/input/dataset2305/(14).mp4 at 40.00 seconds
# Saved frame 9 of /kaggle/input/dataset2305/(14).mp4 at 45.00 seconds
# Saved frame 10 of /kaggle/input/dataset2305/(14).mp4 at 50.00 seconds
# Saved frame 11 of /kaggle/input/dataset2305/(14).mp4 at 55.00 seconds
# Saved frame 12 of /kaggle/input/dataset2305/(14).mp4 at 60.00 seconds
# Saved frame 13 of /kaggle/input/dataset2305/(14).mp4 at 65.00 seconds
# Saved frame 14 of /kaggle/input/dataset2305/(14).mp4 at 70.00 seconds
# Saved frame 15 of /kaggle/input/dataset2305/(14).mp4 at 75.00 seconds
# Saved frame 16 of /kaggle/input/dataset2305/(14).mp4 at 80.00 seconds
# Saved frame 17 of /kaggle/input/dataset2305/(14).mp4 at 85.00 seconds
# Saved frame 18 of /kaggle/input/dataset2305/(14).mp4 at 90.00 seconds
# Saved frame 19 of /kaggle/input/dataset2305/(14).mp4 at 95.00 seconds
# Saved frame 20 of /kaggle/input/dataset2305/(14).mp4 at 100.00 seconds
# Saved frame 21 of /kaggle/input/dataset2305/(14).mp4 at 105.00 seconds
# Saved frame 22 of /kaggle/input/dataset2305/(14).mp4 at 110.00 seconds
# Saved frame 23 of /kaggle/input/dataset2305/(14).mp4 at 115.00 seconds
# Saved frame 24 of /kaggle/input/dataset2305/(14).mp4 at 120.00 seconds
# Saved frame 25 of /kaggle/input/dataset2305/(14).mp4 at 125.00 seconds
# Saved frame 26 of /kaggle/input/dataset2305/(14).mp4 at 130.00 seconds
# Saved frame 27 of /kaggle/input/dataset2305/(14).mp4 at 135.00 seconds
# Saved frame 28 of /kaggle/input/dataset2305/(14).mp4 at 140.00 seconds
# Saved frame 29 of /kaggle/input/dataset2305/(14).mp4 at 145.00 seconds
# Saved frame 30 of /kaggle/input/dataset2305/(14).mp4 at 150.00 seconds
# Saved frame 31 of /kaggle/input/dataset2305/(14).mp4 at 155.00 seconds
# Saved frame 32 of /kaggle/input/dataset2305/(14).mp4 at 160.00 seconds
# Saved frame 33 of /kaggle/input/dataset2305/(14).mp4 at 165.00 seconds
# Saved frame 34 of /kaggle/input/dataset2305/(14).mp4 at 170.00 seconds
# Saved frame 35 of /kaggle/input/dataset2305/(14).mp4 at 175.00 seconds
# Saved frame 36 of /kaggle/input/dataset2305/(14).mp4 at 180.00 seconds
# Saved frame 37 of /kaggle/input/dataset2305/(14).mp4 at 185.00 seconds
# Saved frame 38 of /kaggle/input/dataset2305/(14).mp4 at 190.00 seconds
# Saved frame 39 of /kaggle/input/dataset2305/(14).mp4 at 195.00 seconds
# Saved frame 40 of /kaggle/input/dataset2305/(14).mp4 at 200.00 seconds
# Saved frame 41 of /kaggle/input/dataset2305/(14).mp4 at 205.00 seconds
# Saved frame 42 of /kaggle/input/dataset2305/(14).mp4 at 210.00 seconds
# Saved frame 43 of /kaggle/input/dataset2305/(14).mp4 at 215.00 seconds
# Saved frame 44 of /kaggle/input/dataset2305/(14).mp4 at 220.00 seconds
# Saved frame 45 of /kaggle/input/dataset2305/(14).mp4 at 225.00 seconds
# Saved frame 46 of /kaggle/input/dataset2305/(14).mp4 at 230.00 seconds
# Saved frame 47 of /kaggle/input/dataset2305/(14).mp4 at 235.00 seconds
# Saved frame 48 of /kaggle/input/dataset2305/(14).mp4 at 240.00 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(4).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(4).mp4 at 5.01 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(4).mp4 at 10.02 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(4).mp4 at 15.03 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(4).mp4 at 20.00 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(4).mp4 at 25.02 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(4).mp4 at 30.03 seconds
# Saved frame 7 of /kaggle/input/dataset2305/(4).mp4 at 35.04 seconds
# Saved frame 8 of /kaggle/input/dataset2305/(4).mp4 at 40.01 seconds
# Saved frame 9 of /kaggle/input/dataset2305/(4).mp4 at 45.02 seconds
# Saved frame 10 of /kaggle/input/dataset2305/(4).mp4 at 50.03 seconds
# Saved frame 11 of /kaggle/input/dataset2305/(4).mp4 at 55.00 seconds
# Saved frame 12 of /kaggle/input/dataset2305/(4).mp4 at 60.01 seconds
# Saved frame 13 of /kaggle/input/dataset2305/(4).mp4 at 65.03 seconds
# Saved frame 14 of /kaggle/input/dataset2305/(4).mp4 at 70.04 seconds
# Saved frame 15 of /kaggle/input/dataset2305/(4).mp4 at 75.01 seconds
# Saved frame 16 of /kaggle/input/dataset2305/(4).mp4 at 80.02 seconds
# Saved frame 17 of /kaggle/input/dataset2305/(4).mp4 at 85.03 seconds
# Saved frame 18 of /kaggle/input/dataset2305/(4).mp4 at 90.00 seconds
# Saved frame 19 of /kaggle/input/dataset2305/(4).mp4 at 95.01 seconds
# Saved frame 20 of /kaggle/input/dataset2305/(4).mp4 at 100.02 seconds
# Saved frame 21 of /kaggle/input/dataset2305/(4).mp4 at 105.04 seconds
# Saved frame 22 of /kaggle/input/dataset2305/(4).mp4 at 110.01 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(16).mp4 at 0.04 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(16).mp4 at 5.00 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(16).mp4 at 10.01 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(16).mp4 at 15.01 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(16).mp4 at 20.02 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(16).mp4 at 25.02 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(2).mp4 at 0.03 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(2).mp4 at 5.03 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(2).mp4 at 10.03 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(2).mp4 at 15.03 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(2).mp4 at 20.03 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(2).mp4 at 25.03 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(2).mp4 at 30.03 seconds
# Saved frame 0 of /kaggle/input/dataset2305/(13).mp4 at 0.03 seconds
# Saved frame 1 of /kaggle/input/dataset2305/(13).mp4 at 5.02 seconds
# Saved frame 2 of /kaggle/input/dataset2305/(13).mp4 at 10.00 seconds
# Saved frame 3 of /kaggle/input/dataset2305/(13).mp4 at 15.02 seconds
# Saved frame 4 of /kaggle/input/dataset2305/(13).mp4 at 20.01 seconds
# Saved frame 5 of /kaggle/input/dataset2305/(13).mp4 at 25.02 seconds
# Saved frame 6 of /kaggle/input/dataset2305/(13).mp4 at 30.01 seconds
# Saved frame 7 of /kaggle/input/dataset2305/(13).mp4 at 35.03 seconds
# Saved frame 8 of /kaggle/input/dataset2305/(13).mp4 at 40.01 seconds
# Saved frame 9 of /kaggle/input/dataset2305/(13).mp4 at 45.03 seconds
# Saved frame 10 of /kaggle/input/dataset2305/(13).mp4 at 50.01 seconds
# Saved frame 11 of /kaggle/input/dataset2305/(13).mp4 at 55.03 seconds
# Saved frame 12 of /kaggle/input/dataset2305/(13).mp4 at 60.02 seconds
# Saved frame 13 of /kaggle/input/dataset2305/(13).mp4 at 65.03 seconds
# Saved frame 14 of /kaggle/input/dataset2305/(13).mp4 at 70.02 seconds
# Saved frame 15 of /kaggle/input/dataset2305/(13).mp4 at 75.00 seconds
# Saved frame 16 of /kaggle/input/dataset2305/(13).mp4 at 80.02 seconds
# Saved frame 17 of /kaggle/input/dataset2305/(13).mp4 at 85.00 seconds
# Saved frame 18 of /kaggle/input/dataset2305/(13).mp4 at 90.02 seconds
# Saved frame 19 of /kaggle/input/dataset2305/(13).mp4 at 95.01 seconds
# Saved frame 20 of /kaggle/input/dataset2305/(13).mp4 at 100.03 seconds
# Saved frame 21 of /kaggle/input/dataset2305/(13).mp4 at 105.01 seconds
# Saved frame 22 of /kaggle/input/dataset2305/(13).mp4 at 110.03 seconds
# Saved frame 23 of /kaggle/input/dataset2305/(13).mp4 at 115.01 seconds
# Saved frame 24 of /kaggle/input/dataset2305/(13).mp4 at 120.03 seconds
# Saved frame 25 of /kaggle/input/dataset2305/(13).mp4 at 125.01 seconds
# Saved frame 26 of /kaggle/input/dataset2305/(13).mp4 at 130.03 seconds
# Saved frame 27 of /kaggle/input/dataset2305/(13).mp4 at 135.02 seconds
# Saved frame 28 of /kaggle/input/dataset2305/(13).mp4 at 140.00 seconds
# Saved frame 29 of /kaggle/input/dataset2305/(13).mp4 at 145.02 seconds
# Saved frame 30 of /kaggle/input/dataset2305/(13).mp4 at 150.00 seconds
# Saved frame 31 of /kaggle/input/dataset2305/(13).mp4 at 155.02 seconds
# Saved frame 32 of /kaggle/input/dataset2305/(13).mp4 at 160.01 seconds
# Saved frame 33 of /kaggle/input/dataset2305/(13).mp4 at 165.02 seconds
# Saved frame 34 of /kaggle/input/dataset2305/(13).mp4 at 170.01 seconds
# Saved frame 35 of /kaggle/input/dataset2305/(13).mp4 at 175.03 seconds
# Saved frame 36 of /kaggle/input/dataset2305/(13).mp4 at 180.01 seconds
# Saved frame 37 of /kaggle/input/dataset2305/(13).mp4 at 185.03 seconds
# Saved frame 38 of /kaggle/input/dataset2305/(13).mp4 at 190.01 seconds
# Saved frame 39 of /kaggle/input/dataset2305/(13).mp4 at 195.03 seconds
# Saved frame 40 of /kaggle/input/dataset2305/(13).mp4 at 200.02 seconds
# Saved frame 41 of /kaggle/input/dataset2305/(13).mp4 at 205.00 seconds
# Saved frame 42 of /kaggle/input/dataset2305/(13).mp4 at 210.02 seconds
# Saved frame 43 of /kaggle/input/dataset2305/(13).mp4 at 215.00 seconds
# Saved frame 44 of /kaggle/input/dataset2305/(13).mp4 at 220.02 seconds
# Saved frame 45 of /kaggle/input/dataset2305/(13).mp4 at 225.01 seconds
# Saved frame 46 of /kaggle/input/dataset2305/(13).mp4 at 230.02 seconds
# Saved frame 47 of /kaggle/input/dataset2305/(13).mp4 at 235.01 seconds
# Saved frame 48 of /kaggle/input/dataset2305/(13).mp4 at 240.03 seconds
# Saved frame 49 of /kaggle/input/dataset2305/(13).mp4 at 245.01 seconds
# Saved frame 50 of /kaggle/input/dataset2305/(13).mp4 at 250.03 seconds
# Saved frame 51 of /kaggle/input/dataset2305/(13).mp4 at 255.01 seconds
# Saved frame 52 of /kaggle/input/dataset2305/(13).mp4 at 260.03 seconds
# Saved frame 53 of /kaggle/input/dataset2305/(13).mp4 at 265.02 seconds
# Saved frame 54 of /kaggle/input/dataset2305/(13).mp4 at 270.03 seconds
# Saved frame 55 of /kaggle/input/dataset2305/(13).mp4 at 275.02 seconds
# Saved frame 56 of /kaggle/input/dataset2305/(13).mp4 at 280.00 seconds
# Saved frame 57 of /kaggle/input/dataset2305/(13).mp4 at 285.02 seconds
# Saved frame 58 of /kaggle/input/dataset2305/(13).mp4 at 290.00 seconds
# Saved frame 59 of /kaggle/input/dataset2305/(13).mp4 at 295.02 seconds
# Saved frame 60 of /kaggle/input/dataset2305/(13).mp4 at 300.01 seconds
# Saved frame 61 of /kaggle/input/dataset2305/(13).mp4 at 305.03 seconds
# Saved frame 62 of /kaggle/input/dataset2305/(13).mp4 at 310.01 seconds
# Saved frame 63 of /kaggle/input/dataset2305/(13).mp4 at 315.03 seconds
# Saved frame 64 of /kaggle/input/dataset2305/(13).mp4 at 320.01 seconds
# Saved frame 65 of /kaggle/input/dataset2305/(13).mp4 at 325.03 seconds
# Saved frame 66 of /kaggle/input/dataset2305/(13).mp4 at 330.01 seconds
# Saved frame 67 of /kaggle/input/dataset2305/(13).mp4 at 335.03 seconds
# Saved frame 68 of /kaggle/input/dataset2305/(13).mp4 at 340.02 seconds
# Saved frame 69 of /kaggle/input/dataset2305/(13).mp4 at 345.00 seconds
# Saved frame 70 of /kaggle/input/dataset2305/(13).mp4 at 350.02 seconds
# Saved frame 71 of /kaggle/input/dataset2305/(13).mp4 at 355.00 seconds
# Saved frame 72 of /kaggle/input/dataset2305/(13).mp4 at 360.02 seconds
# Saved frame 73 of /kaggle/input/dataset2305/(13).mp4 at 365.01 seconds
# Saved frame 74 of /kaggle/input/dataset2305/(13).mp4 at 370.02 seconds
# Saved frame 75 of /kaggle/input/dataset2305/(13).mp4 at 375.01 seconds
# Saved frame 76 of /kaggle/input/dataset2305/(13).mp4 at 380.03 seconds
# Saved frame 77 of /kaggle/input/dataset2305/(13).mp4 at 385.01 seconds
# Saved frame 78 of /kaggle/input/dataset2305/(13).mp4 at 390.03 seconds
# Saved frame 79 of /kaggle/input/dataset2305/(13).mp4 at 395.01 seconds
# Saved frame 80 of /kaggle/input/dataset2305/(13).mp4 at 400.03 seconds

# %%
# !pip install zip_files -q

# %%
# !zip-folder --auto-root --outfile /kaggle/working/vidframes8.zip /kaggle/working/data7
